# %%
# 1. Import the factory function that builds the agent
from agents.cbre_agent import create_cbre_agent

# 2. Create an instance of the agent
# All the complex setup is hidden inside this function call.
cbre_agent = create_cbre_agent()

# 3. Define your goal in natural language and run the agent!
user_prompt = "Find and download all market reports from CBRE."

result = cbre_agent.invoke({
    "input": user_prompt
})

print("\n\n✅ Agent task finished.")
print(f"Final Result: {result['output']}")
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `cbre_report_archiver` with `{}`
#
#
# Found 163 existing PDF reports in 'CBRE_Reports'.
# 🤖 Selenium WebDriver Initialized.
# Navigated to: https://www.cbre.com/insights#market-reports
# ✓ Accepted cookies.
# ✓ Clicked 'Market Reports' tab.
# ✓ Switched to iframe.
# Applying filter: 'Property Type' -> 'Industrial and Logistics'...
# ✓ Filter applied.
# Applying filter: 'Country' -> 'United States'...
# ✓ Filter applied.
# Sorting results by 'Most Recent'...
# ✓ Sort option applied.
# 📄 Scraping Page 1...
#    ✅ Found matching report: Tucson Industrial Figures Q2 2025
#    ✅ Found matching report: Nashville Industrial Figures Report Q2 2025
#    ✅ Found matching report: Northern Colorado Industrial Figures H1 2025
#    ✅ Found matching report: Colorado Springs Industrial Figures H1 2025
#    ✅ Found matching report: Ventura Industrial Figures Q2 2025
#    ✅ Found matching report: Greater San Fernando Industrial Figures Q2 2025
# ...
